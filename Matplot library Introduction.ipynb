# %% [markdown]
# # Matplot library introduction

# %% [markdown]
# ### Histogram Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
random_list = np.random.randint(1, 100, size= 40)
random_list
# Out:
# array([75, 11, 11, 47,  7, 74, 37, 76, 34, 32, 12, 54, 35,  1, 33, 52, 73,
#        27, 39, 97, 84, 99, 53, 93, 75, 11, 54, 34, 73,  1, 79, 86, 81, 76,
#        20, 98, 48, 43, 86, 50])

# %%
plt.hist(x=random_list)
# plt.xticks([2, 4, 8, 10, 20])
plt.show()

# %% [markdown]
# ### Line Plot

# %%
month = ['August', 'September', 'October', 'November', 'December']
students = [60, 70, 20, 34, 50]

plt.plot(month, students)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
height = [5.5, 4.8, 5.5, 6, 5.4, 5.8]
weight = [60, 37, 70, 120, 47, 60]

plt.scatter(x=height, y=weight)
plt.show()

# %% [markdown]
# ### Bar chart

# %%
import pandas as pd

# %%
raw_data = {'Name': ['upes', 'dit', 'gehu', 'dit', 'upes', 'dit', 'upes', 'gehu', 'dit', 'upes', 'upes', 'dit', 'dit', 'dit', 'gehu', 'upes', 'gehu']}

data = pd.DataFrame(data=raw_data)

# %%
font = {'family': 'serif',
        'weight': 'bold',
        'size': 20,
        }
plt.bar(x=data.Name.unique(), height=data.Name.value_counts())
plt.xlabel('College Names', fontdict=font)
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
unique_colleges = data.Name.unique()

# %%
unique_colleges
# Out:
# array(['upes', 'dit', 'gehu'], dtype=object)

# %%
sizes = data.Name.value_counts()
sizes
# Out:
# dit     7
# upes    6
# gehu    4
# Name: Name, dtype: int64

# %%
plt.pie(sizes, labels=unique_colleges, autopct='%.2f', explode=(0, 0.1, 0))
plt.show()

# %% [markdown]
# ### Box Plot

# %%
box_data = np.random.randint(10, 50, size=50)
box_data
# Out:
# array([49, 16, 27, 26, 25, 29, 37, 38, 44, 28, 15, 21, 10, 25, 14, 46, 31,
#        41, 13, 44, 27, 35, 36, 42, 12, 24, 14, 30, 19, 38, 46, 46, 26, 47,
#        10, 18, 19, 11, 39, 44, 48, 28, 13, 32, 48, 49, 17, 48, 35, 42])

# %%
outliers_data = np.random.randint(40, 150, size=10)
outliers_data
# Out:
# array([139,  80,  74,  60, 148,  66,  40, 134,  48, 104])

# %%
new_data = np.concatenate((box_data, outliers_data), axis=0)
new_data
# Out:
# array([ 49,  16,  27,  26,  25,  29,  37,  38,  44,  28,  15,  21,  10,
#         25,  14,  46,  31,  41,  13,  44,  27,  35,  36,  42,  12,  24,
#         14,  30,  19,  38,  46,  46,  26,  47,  10,  18,  19,  11,  39,
#         44,  48,  28,  13,  32,  48,  49,  17,  48,  35,  42, 139,  80,
#         74,  60, 148,  66,  40, 134,  48, 104])

# %%
plt.boxplot(new_data)
plt.show()
